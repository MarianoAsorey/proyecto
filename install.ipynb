# %%
packages <- c(
  "tidyverse",
  "ggcorrplot",
  "maps",
  "factoextra",
  "ggrepel",
  "janitor",
  "treemapify",
  "scales"
)

# Instala solo los que no estén ya instalados:
install.packages(setdiff(packages, rownames(installed.packages())))
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘rbibutils’, ‘Deriv’, ‘microbenchmark’, ‘Rdpack’, ‘doBy’, ‘SparseM’, ‘MatrixModels’, ‘minqa’, ‘nloptr’, ‘reformulas’, ‘RcppEigen’, ‘lazyeval’, ‘litedown’, ‘carData’, ‘Formula’, ‘pbkrtest’, ‘quantreg’, ‘lme4’, ‘crosstalk’, ‘estimability’, ‘mvtnorm’, ‘numDeriv’, ‘corrplot’, ‘markdown’, ‘png’, ‘jpeg’, ‘plyr’, ‘viridis’, ‘car’, ‘DT’, ‘ellipse’, ‘emmeans’, ‘flashClust’, ‘leaps’, ‘multcompView’, ‘scatterplot3d’, ‘ggsci’, ‘cowplot’, ‘ggsignif’, ‘gridExtra’, ‘polynom’, ‘rstatix’, ‘shades’, ‘gridtext’, ‘reshape2’, ‘abind’, ‘dendextend’, ‘FactoMineR’, ‘ggpubr’, ‘snakecase’, ‘ggfittext’
